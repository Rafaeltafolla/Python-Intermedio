# %%
import pandas as pd 

df = pd.read_csv('cr7.csv')

df.head()
# Out:
#   Season               Competition      Matchday        Date Venue  \
# 0  3-Feb             Liga Portugal             6   10/7/2002     H
# 1  3-Feb             Liga Portugal             6   10/7/2002     H
# 2  3-Feb             Liga Portugal             8  10/26/2002     A
# 3  3-Feb  Taca de Portugal Placard  Fourth Round  11/24/2002     H
# 4  3-Feb  Taca de Portugal Placard   Fifth Round  12/18/2002     H
#
#           Club                 Opponent Result Playing_Position Minute  \
# 0  Sporting CP            Moreirense FC   3:00               LW     34
# 1  Sporting CP            Moreirense FC   3:00               LW     90
# 2  Sporting CP              Boavista FC   1:02              NaN     88
# 3  Sporting CP             CD Estarreja   4:01              NaN     67
# 4  Sporting CP  FC Oliveira do Hospital   8:01              NaN     13
#
#   At_score               Type     Goal_assist
# 0     2:00           Solo run             NaN
# ...

# %%
import pandas as pd 

df = pd.read_csv('autos_usados.csv')

df.head()
# Out:
#         brand    model  price (eur)                     engine  year  \
# 0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style  2016
# 1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno  2014
# 2         BMW  Serie 5        13490               530d Touring  2011
# 3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)  2018
# 4        Opel    Corsa        10460       1.4 Expression 90 CV  2016
#
#    mileage (kms)      fuel     gearbox    location
# 0          67000  Gasolina      Manual  Granollers
# 1         104868    Diésel      Manual  Viladecans
# 2         137566    Diésel  Automatica  Viladecans
# 3          44495  Gasolina      Manual  Viladecans
# 4          69800  Gasolina      Manual  Sabadell 1
